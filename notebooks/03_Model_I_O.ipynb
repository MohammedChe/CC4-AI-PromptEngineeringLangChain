# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key:")
# Out:
# Enter Your OpenAI API Key:··········

# %%
os.environ["COHERE_API_KEY"] = getpass.getpass("Cohere API Key:")
# Out:
# Cohere API Key:··········

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = getpass.getpass("HF API Key:")
# Out:
# HF API Key:··········

# %% [markdown]
# 🌟 **Model I/O Essentials**:
#    1. **Prompts**: Tailor AI responses with customisable templates.
#    2. **Language Models**: Choose between text or conversation processing.
#    3. **Output Parsers**: Tidy up AI outputs for easy application.
#
# 🔁 **Workflow Overview**:
#    - Select model type (LLM or Chat) for your task.
#    - Design a prompt to guide the model.
#    - Run input through your chosen model.
#    - Use Output Parser for neat results.
#
# <img src="https://legacy-us-images.foundryco.app/images/article/2023/09/langchain-01-100945666-orig.jpg?auto=webp&quality=85,70">
#
# 💡 **Deep Dive into Language Models**:
#    - Chat models are dialogue-focused LLMs.
#    - Swap easily between LLMs and Chat models thanks to a shared interface.
#
# 🤔 **LLMs vs. Chat Models**:
#    - **LLMs**: Ideal for text responses.
#    - **Chat Models**: Great for chat-like interactions.
#
# 🎛️ **Using LLMs Effectively**:
#    - LLM class connects to various AI providers.
#    - **Predict Method**: Quick, text-based replies.
#    - **Generate Method**: Detailed responses with extras.
#
# 👩‍💻 **Practical Application**:
#    - Explore LLMs from different sources.
#    - Focus on predict and generate capabilities.

# %%
from langchain_openai import ChatOpenAI
from langchain_cohere.llms import Cohere
# from langchain_huggingface import HuggingFacePipeline 

openai_llm = ChatOpenAI(model="gpt-5-nano-2025-08-07")
# see: https://platform.openai.com/docs/models 

cohere_llm = Cohere()

# huggingface_llm = HuggingFaceHub(
#     repo_id="mistralai/Mistral-7B-Instruct-v0.2",
#     model_kwargs={
#         "temperature": 0.01,
#         "max_length": 4096,
#         "do_sample":True,
#         }
# )

# %%
prompt = "How do I become an AI Engineer?"

# %%
openai_response = openai_llm.invoke(prompt)
print(openai_response.content)
# Out:
# Becoming an AI Engineer involves several steps, including education, skill development, and practical experience. Here’s a guide to help you start your journey:
#
# ### 1. Educational Background:
# - **Bachelor’s Degree**: Start with a bachelor's degree in computer science, software engineering, data science, mathematics, or a related field. This provides a strong foundation in programming, algorithms, and statistics.
# - **Master’s Degree (Optional)**: Many AI Engineers pursue a master's degree or PhD in artificial intelligence, machine learning, or data science to deepen their expertise and improve job prospects.
#
# ### 2. Develop Core Skills:
# Focus on building a strong skill set in the following areas:
#
# - **Programming Languages**: Proficiency in languages like Python, R, Java, C++, or Scala, as Python is widely used in AI development.
# - **Mathematics and Statistics**: A good grasp of linear algebra, calculus, probability, and statistics is crucial for understanding algorithms and data models.
# - **Machine Learning**: Learn about supervised and unsupervised learning, deep learning, reinforcement learning, and natural language processing (NLP).
# - **Data Handling**: Gain experience with data manipulation, cleaning, and analysis using libraries like Pandas, NumPy, and tools like SQL for databases.
# - **AI Frameworks and Libraries**: Familiarize yourself with frameworks such as TensorFlow, PyTorch, Keras, Scikit-learn, and others relevant to your applications.
#
# ### 3. Practical Experience:
# - **Projects**: Work on real-world projects. You can find datasets online (like Kaggle or UCI Machine Learning Repository) to practice building and deploying models. Consider:
#   - Building predictive models
#   - Creating applications using NLP
#   - Developing computer vision applications
# - **Internships**: Seek internships or entry-level positions that provide hands-on experience in AI and machine learning. This can enhance your resume and skillset.
#
# ### 4. Build a Portfolio:
# - Create a portfolio showcasing your projects, code samples, and contributions to open-source projects. This can be a personal website or a GitHub repository.
#
# ### 5. Continuous Learning:
# - Stay updated on the latest trends and research in AI. Follow relevant journals, blogs, and online courses (e.g., Coursera, edX, Udacity).
# - Participate in AI and data science competitions (like Kaggle) to challenge your skills and learn from the community.
#
# ### 6. Networking:
# - Connect with professionals in the field through LinkedIn, meetups, and conferences. Networking can lead to job opportunities and collaborations.
#
# ### 7. Job Search:
# - Apply for AI Engineer positions. Tailor your resume to highlight relevant skills and experiences. Be prepared for technical interviews that may include coding tests and whiteboard challenges.
#
# ### 8. Certifications (Optional):
# - Consider obtaining certifications in machine learning, data science, or specific AI frameworks to strengthen your qualifications.
#
# ### Summary:
# Becoming an AI Engineer requires a mixture of education, technical skills, practical experience, and ongoing learning. By building your expertise in programming, mathematics, machine learning, and engaging with the community, you can carve out a successful career in this rapidly evolving field.

# %%
cohere_response = cohere_llm.invoke(prompt)
print(cohere_response)
# Out:
#  Becoming an AI engineer requires a combination of technical skills, knowledge, and practical experience in the field. Here are some steps you can follow to start your career as an AI engineer:
#
# 1. Education: Complete a Bachelor's degree in a field related to AI, such as computer science, data science, or software engineering. Some universities may offer specialized degrees or minors in AI or machine learning. A solid foundation in programming, algorithms, data structures, and statistics is essential.
#
# 2. Core Skills: Develop a strong understanding of AI fundamentals, including machine learning algorithms, natural language processing, computer vision, and data analytics. Skills in programming languages commonly used in AI, such as Python, R, and TensorFlow, are also essential.
#
# 3. Specialize: Focus on a specific area of AI that aligns with your interests and skills. This could be machine learning, natural language processing, computer vision, or knowledge representation. Study topics like supervised learning, unsupervised learning, reinforcement learning, deep learning, and neural networks.
#
# 4. Projects: Experiment with AI projects to apply your knowledge and develop practical experience. Choose projects that interest you and create small, manageable goals to allow you to learn by doing. Explore libraries like Scikit-learn, Keras

# %%
hf_response = huggingface_llm.invoke(prompt)
print(hf_response)
# Out:
# How do I become an AI Engineer?
#
# To become an AI Engineer, you will typically need a strong foundation in computer science, mathematics, and programming. Here are some steps you can take to pursue a career in AI Engineering:
#
# 1. Earn a Bachelor's or Master's Degree in Computer Science, Mathematics, or a related field. A strong foundation in linear algebra, calculus, statistics, and programming is essential.
# 2. Learn programming languages commonly used in AI Engineering such as Python

# %% [markdown]
# # Compare model outputs

# %%
from langchain_classic.model_laboratory import ModelLaboratory # will not work in the future

model_lab = ModelLaboratory.from_llms([openai_llm, cohere_llm, huggingface_llm])

model_lab.compare(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_classic.model_laboratory import ModelLaboratory # will not work in the future
# ----> 3 model_lab = ModelLaboratory.from_llms([openai_llm, cohere_llm, huggingface_llm])
#       5 model_lab.compare(prompt)
#
# NameError: name 'openai_llm' is not defined

# %% [markdown]
# # Working with Chat models
#
# We'll stick to the OpenAI chat models for this section.
#
# The chat model interface is based around messages rather than raw text.
#
# The types of messages currently supported in LangChain are `AIMessage`, `HumanMessage`, `SystemMessage`.

# %%
from langchain_openai import ChatOpenAI

from langchain.messages import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

chat = ChatOpenAI(model="gpt-5-nano-2025-08-07")

messages = [
    SystemMessage(content="You are a tough love career coach who gets to the point and pushes your mentees to be their best."),
    HumanMessage(content="How do I become an AI engineer?")
]

response = chat.invoke(messages)

print(response.content)
# Out:
# Alright, let’s cut to the chase. Here’s your game plan to become an AI engineer:
#
# 1. **Get Educated**: You need a solid foundation in computer science. Aim for at least a bachelor’s degree in computer science, data science, or a related field. Consider a master’s if you're serious about standing out.
#
# 2. **Master the Basics**: You're going to need mathematics—linear algebra, calculus, probability, and statistics. Get comfortable with these subjects; they are the backbone of AI.
#
# 3. **Learn Programming**: Python is the language of choice in AI, so become proficient in it. Don’t stop there; familiarize yourself with C++, R, and Java if you can.
#
# 4. **Dive into AI and Machine Learning**: Enroll in online courses or bootcamps that focus on AI and machine learning. Platforms like Coursera, edX, and Udacity have great options. Focus on practical projects.
#
# 5. **Work with Data**: Get hands-on experience with data—cleaning, analyzing, and visualizing it. Learn about databases and tools like SQL, Pandas, and NumPy.
#
# 6. **Build Projects**: This is where theory meets reality. Work on real-life projects or contribute to open source. Tailor these to showcase your skills – build a portfolio to prove you can deliver results.
#
# 7. **Networking**: Get involved in the AI community. Attend conferences, meetups, and webinars. Connect with professionals on LinkedIn, and don’t hesitate to reach out for advice or mentorship.
#
# 8. **Get Experience**: Look for internships, part-time roles, or freelance gigs in AI. You need practical, real-world experience to break into the field.
#
# 9. **Stay Updated**: The field of AI is constantly evolving. Follow reputable sources, read research papers, and keep your skills sharp.
#
# 10. **Be Persistent**: Don’t expect instant success. Failure is part of the process, but persistence will get you there.
#
# Now, get moving and make it happen! No more excuses. You want this? Prove it with action.

# %% [markdown]
# # 💬 **Prompt Fundamentals in Language Models**
#
#    - **Role of Prompts**: Set the stage for AI responses, from sentence completions to Q&A.
#    - **Impact**: Determines how the AI will reply.
#
# # 🛠️ **Designing Effective Prompts**
#
#    - **Key Elements**: Clarity, context, user query, and a signal for AI to respond.
#
#    - **Goal**: Direct AI towards the intended response.
#
# # 📐 **Using Prompt Templates**
#    - **Function**: Acts as a blueprint for crafting consistent, effective prompts.
#    - **Advantage**: Ensures AI receives appropriate input for the expected output.
#
# # 🎯 **Simplicity in Explanation**
#    - Concise and straightforward, making the concept easy to understand without deep technical details.

# %%
from langchain_core.prompts import PromptTemplate

# Define a simple prompt template as a Python string

prompt_template = PromptTemplate.from_template("""
Human: What is the capital of {place}?
AI: The capital of {place} is {capital}
""")

prompt = prompt_template.format(place="Ireland", capital="Dublin")

print(prompt)
# Out:
# Human: What is the capital of Ireland?
# AI: The capital of Ireland is Dublin

# %%
# No Input Variable
no_input_prompt = PromptTemplate(input_variables=[], template="Tell me a joke.")
print(no_input_prompt.format())

# One Input Variable
one_input_prompt = PromptTemplate(input_variables=["adjective"], template="Tell me a {adjective} joke.")
print(one_input_prompt.format(adjective="funny"))

# Multiple Input Variables
multiple_input_prompt = PromptTemplate(
 input_variables=["adjective", "content"],
 template="Tell me a {adjective} joke about {content}."
)

multiple_input_prompt = multiple_input_prompt.format(adjective="funny", content="chickens")
print(multiple_input_prompt)
# Out:
# Tell me a joke.
# Tell me a funny joke.
# Tell me a funny joke about chickens.

# %% [markdown]
# Pass a prompt template to an LLM

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-nano-2025-08-07")

prompt_template = PromptTemplate.from_template(
    template="Write a {length} story about: {content}"
)

prompt = prompt_template.format(
    length="2-sentence",
    content="Dublin, Ireland, the hometown of the legendary writer, James Joyce"
)

response = llm.invoke(input=prompt)

response

# %%
response = llm.predict(text=prompt)

response
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `predict` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# 'In the bustling city of Sacramento, CA, under the vast expanse of the starlit Californian sky, was born Harpreet Sahota, a prodigy who would later revolutionize the world as a legendary data scientist. His groundbreaking algorithms and innovative data models forever transformed how humanity harnessed the power of information, leaving an indelible mark on his beloved hometown and beyond.'

# %% [markdown]
# # Output parsers
#
# - Output parsers shape the AI's text output into a more usable form, like a database entry or a JSON object.
#
# **Main Uses:**
#
# 1. They turn a block of text into organized data.
# 2. They can guide the AI on how to format its responses for consistency and ease of use.
#
# This stripped-down explanation keeps the focus on the purpose and function of output parsers, suitable for a quick overview during a presentation.

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers.list import ListOutputParser

# %% [markdown]
# Without parsing output

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-nano-2025-08-07")

prompt = PromptTemplate(
    template="List 3 {things}",
    input_variables=["things"])

response = llm.invoke(input=prompt.format(things="sports that don't use balls"))
print(response.content)
# Out:
# - Swimming
# - Boxing
# - Fencing

# %% [markdown]
# Instantiate output parser

# %%
output_parser = CommaSeparatedListOutputParser()

format_instructions = output_parser.get_format_instructions()

print(format_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %% [markdown]
# Now let's see how to use the parsers instructions in the prompt. Note, as of the version of LangChain we are using ,

# %%
prompt = PromptTemplate(
    template="List 3 {things}.\n{format_instructions}",
    input_variables=["things"],
    partial_variables={"format_instructions": format_instructions})

output = llm.invoke(input=prompt.format(things="sports that don't use balls"))

print(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 prompt = PromptTemplate(
#       2     template="List 3 {things}.\n{format_instructions}",
#       3     input_variables=["things"],
#       4     partial_variables={"format_instructions": format_instructions})
#       6 output = llm.invoke(input=prompt.format(things="sports that don't use balls"))
#       8 print(output)
#
# NameError: name 'PromptTemplate' is not defined

# %% [markdown]
# Finally, we can parse the output to a list (Python object)

# %%
output_parser.parse(output.content)
# Out:
# ['swimming', 'gymnastics', 'wrestling']

# %% [markdown]
# # 🔗 **LangChain Expression Language (LCEL) Overview**:
#    - **Purpose**: Simplify building complex chains from basic components.
#    - **Features**: Supports streaming, parallelism, and logging.
#
# ### 🛠️ Basic Use Case: Prompt + Model + Output Parser
#    - **Common Approach**: Link a prompt template with a model.
#    - **Chain Mechanism**: Using the `|` symbol, like a Unix pipe, to connect components.
#    - **Process Flow**: User input → Prompt Template → Model → Output Parser.
#
# ### 🧩 Understanding the Components
#    - **Step-by-Step**:
#      - User input is processed by the prompt template.
#      - Prompt template's output goes to the model.
#      - Model's output is refined by the output parser.
#    - **Example Code**: `chain = prompt | model | output_parser` shows how to combine components into a single LCEL chain.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template("Write a 4-bar rap verse about {topic}")

model = ChatOpenAI(model="gpt-5-nano-2025-08-07")

output_parser = StrOutputParser()

chain = prompt | model | output_parser

chain.invoke({"topic": "rainy days in Ireland"})
# Out:
# 'Rain drums on Dublin rooftops, hoodie tight, I ride the day\nEmerald hills blur through the mist, the Liffey glints and guides my way\nUmbrellas bloom like neon crops, street poetry riding the spray\nI spit through the drizzle, turning rain into rhythm on the way'
