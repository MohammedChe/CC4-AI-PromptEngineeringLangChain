# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key:")
open_ai_model = "gpt-5-nano-2025-08-07"
# Out:
# Enter Your OpenAI API Key:··········

# %% [markdown]
# # Partial Prompt Templates in LangChain
#
# **Partial Prompt Templates in LangChain:**
#
# - 🔧 **Flexibility** : Set some template values early for a head start.
#
# - **Two Creation Methods**:
#    1. 🧵 **Strings** : Lock in certain known values upfront.
#    2. 🔄 **Functions** : Use for variables that change, like time.
#
# - 🌍 **Real-World Use** : Pre-fill static info like name and place, add dynamic details like time later.
#
# Partial templates maintain structure while streamlining the prompting process.

# %%
from langchain_core.prompts import PromptTemplate

# %%
prompt = PromptTemplate(
    template="Hello, {UserName}! Hope you're enjoying {UserActivity}.",
    input_variables=["UserName", "UserActivity"]
)

# %%
prompt.format(UserName="Alice")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 prompt.format(UserName="Alice")
#
# File ~/IADT_local/25_26/AI/Prompt_Engineering_LangChain/Prompt_Engineering_LangChain/.venv/lib/python3.14/site-packages/langchain_core/prompts/prompt.py:198, in PromptTemplate.format(self, **kwargs)
#     189 """Format the prompt with the inputs.
#     190
#     191 Args:
#    (...)    195     A formatted string.
#     196 """
#     197 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 198 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/string/__init__.py:205, in Formatter.format(self, format_string, *args, **kwargs)
#     204 def format(self, format_string, /, *args, **kwargs):
# --> 205     return self.vformat(format_string, args, kwargs)
#
# File ~/IADT_local/25_26/AI/Prompt_Engineering_LangChain/Prompt_Engineering_LangChain/.venv/lib/python3.14/site-packages/langchain_core/utils/formatting.py:33, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      28     msg = (
#      29         "No arguments should be provided, "
#      30         "everything should be passed as keyword arguments."
#      31     )
#      32     raise ValueError(msg)
# ---> 33 return super().vformat(format_string, args, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/string/__init__.py:209, in Formatter.vformat(self, format_string, args, kwargs)
#     207 def vformat(self, format_string, args, kwargs):
#     208     used_args = set()
# --> 209     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     210     self.check_unused_args(used_args, args, kwargs)
#     211     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/string/__init__.py:250, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     246     auto_arg_index = False
#     248 # given the field_name, find the object it references
#     249 #  and the argument it came from
# --> 250 obj, arg_used = self.get_field(field_name, args, kwargs)
#     251 used_args.add(arg_used)
#     253 # do any conversion on the resulting object
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/string/__init__.py:315, in Formatter.get_field(self, field_name, args, kwargs)
#     312 def get_field(self, field_name, args, kwargs):
#     313     first, rest = _string.formatter_field_name_split(field_name)
# --> 315     obj = self.get_value(first, args, kwargs)
#     317     # loop through the rest of the field_name, doing
#     318     #  getattr or getitem as needed
#     319     for is_attr, i in rest:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/string/__init__.py:272, in Formatter.get_value(self, key, args, kwargs)
#     270     return args[key]
#     271 else:
# --> 272     return kwargs[key]
#
# KeyError: 'UserActivity'

# %%
partial_prompt = prompt.partial(UserName="Alice")

# %%
partial_prompt
# Out:
# PromptTemplate(input_variables=['UserActivity'], input_types={}, partial_variables={'UserName': 'Alice'}, template="Hello, {UserName}! Hope you're enjoying {UserActivity}.")

# %%
print(partial_prompt.format(UserActivity="your time at the Wonderland Resort and chasing our rabbits!"))
# Out:
# Hello, Alice! Hope you're enjoying your time at the Wonderland Resort and chasing our rabbits!.

# %% [markdown]
# # Partial with Functions
#
#
# **Partial with Functions in LangChain:**
#
# - 💡 **Dynamic Data** : Automate real-time variable updates in prompts.
# - 🔄 **Ideal for Live Updates** : Perfect for inputs like the day's weather.
# - ⚙️ **Efficiency** : No need for manual edits or repetitive inputs.
#
# 🌤️ -> 📜 Use a function in the template for live data, like weather, to make your prompts as current as the moment.

# %%
from datetime import datetime

def _get_weather():
    # For the sake of this example, let's assume this function fetches the current weather.
    # In a real-world scenario, this could be integrated with a weather API.
    weather_conditions = ["sunny", "rainy", "cloudy", "snowy"]

    return weather_conditions[datetime.now().day % 4]  # Just a mock way to change weather daily

prompt = PromptTemplate(
    template="On this {weather} day, tell me a {mood} story.",
    input_variables=["mood", "weather"]
)

partial_prompt = prompt.partial(weather=_get_weather)

print(partial_prompt.format(mood="heartwarming"))

prompt = PromptTemplate(
    template="On this {weather} day, tell me a {mood} story.",
    input_variables=["mood", "weather"],
    partial_variables={"weather": _get_weather}
)
print(prompt.format(mood="adventurous"))
# Out:
# On this sunny day, tell me a heartwarming story.
# On this sunny day, tell me a adventurous story.

# %%
prompt = PromptTemplate.from_template(template="On this {weather} day, tell me a {mood} story.")

prompt = PromptTemplate.from_template(
    template="On this {weather} day, tell me a {mood} story.",
    partial_variables={"weather": _get_weather}
)

print(prompt.format(mood="adventurous"))
# Out:
# On this sunny day, tell me a adventurous story.
