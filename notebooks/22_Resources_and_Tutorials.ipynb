# %% [markdown]
# # LangChain Resources
#
#
# - [Project: Deep Research with LangGraph](https://academy.langchain.com/courses/take/deep-research-with-langgraph/lessons/67513388-course-overview)
#   - **What you will learn:**
#     - Design decisions: Why / How behind design decisions.
#     - Research agents: Agent design / prompting / using MCP.
#     - Multi-agent systems: Multi-agent design / prompting.
#     - Evaluation: Evaluating sub-components.
#   - Slides: [Deep Research From Scratch Slides.pdf](https://files.cdn.thinkific.com/file_uploads/967498/attachments/1e4/794/f99/Deep_Research_From_Scratch_Slides.pdf)
#   - Download Notebook on [GitHub](https://github.com/langchain-ai/deep_research_from_scratch.git)
#
#
# - [LangChain Academy](https://academy.langchain.com/collections)
#
# ---
